# %% [markdown]
# # Baseline Experiments for Auto-Flashcards
#
# Этот ноутбук используется для базовых экспериментов с baseline-моделью
# из модуля `ml/models/baseline.py`.

# %%
import os
import sys

# current_dir = .../bachelor-2025-team-codex/notebooks
current_dir = os.getcwd()

# project_root = .../bachelor-2025-team-codex
project_root = os.path.dirname(current_dir)

# добавляем корень проекта в sys.path
if project_root not in sys.path:
    sys.path.append(project_root)

print("Текущая директория:", current_dir)
print("Корень проекта:", project_root)
# Out:
# Текущая директория: c:\Users\albad\Desktop\dev\bachelor-2025-team-codex\notebooks
# Корень проекта: c:\Users\albad\Desktop\dev\bachelor-2025-team-codex

# %%
from ml.models.baseline import generate_flashcards

text = "FastAPI — это современный веб-фреймворк для Python. Он позволяет быстро создавать API."
cards = generate_flashcards(text)
cards
# Out:
# [{'question': 'О чём говорится в предложении №1?',
#   'answer': 'FastAPI — это современный веб-фреймворк для Python'},
#  {'question': 'О чём говорится в предложении №2?',
#   'answer': 'Он позволяет быстро создавать API'}]
